# %% [markdown]
# ## Creatging_databases_tables ##

# %% [markdown]
# #### **Cargar el SQL en Jupyter** ####

# %%
# %load_ext sql
# %sql sqlite://
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# #### **Creacion de Base de datos** ###
# - CREATE DATABASE prueba;

# %%
"Crea una base de datos para SQLite"
# %sql sqlite:///prueba.db

# %% [markdown]
# #### **Eliminar base de datos** ###
#
# - DROP DATABASE prueba;

# %% [markdown]
# Se elimina directamente en el sqlite

# %% [markdown]
# #### **Mostrar base de datos** ####
# - show databases;

# %%
"Muestra un listado de base de datos para sqlite"
# %sql PRAGMA database_list;
# Out:
#    sqlite://
#  * sqlite:///prueba.db
# Done.
# [(0, 'main', 'c:\\Users\\aguiar3\\OneDrive - Faurecia\\IA Project\\Training\\SQL\\1\\UDEMY Training\\MySQLTraining1-Colt Steele\\prueba.db')]

# %% [markdown]
# #### **Usar base de datos** ###
# - USE prueba,

# %%
"Usar la base de datos que necesitas"
# %sql sqlite:///prueba.db

# %% [markdown]
# #### **DataTypes** ####
#
# Numerical
#
# - INT
# - DECIMAL
# - FLOAT
# - DOUBLE
# - BIT
#
# String
#
# - CHAR
# - VARCHAR
# - TEXT
# - ENUM

# %% [markdown]
# ##### Excercise #####
#
# - username VARCHAR(15)
# - contect VARCHAR (140)
# - numoffavorites INT

# %% [markdown]
# #### **Crear Tablas** ###

# %%
# %%sql
#
# CREATE TABLE tabla1(
#     username VARCHAR(15),
#     contect VARCHAR(140),
#     favorites INT
# );
# Out:
#    sqlite://
#  * sqlite:///prueba.db
# (sqlite3.OperationalError) table tabla1 already exists
# [SQL: CREATE TABLE tabla1(
#     username VARCHAR(15),
#     contect VARCHAR(140),
#     favorites INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# #### **Mostrar Trablas** ####

# %% [markdown]
# - SHOW tables;
# - SHOW COLUMNS FROM table1;
# - DESC Cats;

# %%
#Para mostrar tablas
# %%sql
SELECT name
FROM sqlite_master
WHERE type="table";
# Out:
#    sqlite://
#  * sqlite:///prueba.db
# Done.
# [('tabla1',)]

# %%
#Para mostrar interiro de la tabla
# %%sql
PRAGMA table_info(tabla1);
# Out:
#    sqlite://
#  * sqlite:///prueba.db
# Done.
# [(0, 'username', 'VARCHAR(15)', 0, None, 0),
#  (1, 'contect', 'VARCHAR(140)', 0, None, 0),
#  (2, 'favorites', 'INT', 0, None, 0)]

# %% [markdown]
# #### **Destruir tablas** ####

# %%
# %%sql
# DROP TABLE tabla1;
# Out:
#    sqlite://
#  * sqlite:///prueba.db
# Done.
# []

# %% [markdown]
# #### **Comentarios** ####
#
# -- Nota
