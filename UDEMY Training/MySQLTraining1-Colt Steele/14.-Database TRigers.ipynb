# %%
# %load_ext sql

# %%
# %sql sqlite:///tvshows.db

# %% [markdown]
# #### **TRIGGER SINTAX** ###

# %% [markdown]
# ```sql
# CREATE TRIGGER triger_name
#     trigger_time trigger_event ON table_name FOR EACH ROW
#     BEGIN
#     END;

# %% [markdown]
# ## 1. Conceptos clave
#
# | Concepto | Descripción | Opciones | Notas importantes |
# |----------|-------------|----------|-------------------|
# | **Trigger** | Código SQL que se ejecuta automáticamente cuando ocurre un evento en una tabla. | — | No se ejecuta manualmente; siempre depende de un evento. |
# | **Trigger Time** | Momento en que corre el trigger respecto al evento. | `BEFORE`, `AFTER` | BEFORE = antes de aplicar el cambio; AFTER = después del cambio. |
# | **Trigger Event** | Tipo de acción que dispara el trigger. | `INSERT`, `UPDATE`, `DELETE` | Solo estos tres eventos existen en MySQL. |
# | **Tabla objetivo** | La tabla en la que ocurre el evento. | Cualquier tabla existente | El trigger pertenece a una tabla específica. |

# %% [markdown]
# # 📘 TABLA MAESTRA ÚNICA — TRIGGERS EN MySQL
#
# | Tema | Detalle |
# |------|---------|
# | **¿Qué es un Trigger?** | Código SQL que se ejecuta automáticamente cuando ocurre un evento (insert/update/delete) en una tabla. |
# | **Propósito general** | Automatizar acciones, validar datos, generar registros históricos, actualizar otras tablas. |
# | **Trigger Time (cuándo se ejecuta)** | BEFORE (antes de aplicar el cambio), AFTER (después de aplicar el cambio). |
# | **Trigger Event (qué lo activa)** | INSERT (nuevo registro), UPDATE (registro modificado), DELETE (registro eliminado). |
# | **Tabla objetivo** | La tabla sobre la cual ocurre el evento que dispara el trigger. |
# | **Sintaxis base** | `CREATE TRIGGER nombre BEFORE/AFTER INSERT/UPDATE/DELETE ON tabla FOR EACH ROW BEGIN … END;` |
# | **Concepto clave "FOR EACH ROW"** | El trigger corre 1 vez por cada fila afectada. |
# | **Uso 1: Validación de datos** | Ejemplo: evitar insertar usuarios menores de 18 años con BEFORE INSERT. |
# | **Uso 2: Auditoría / Logs** | Guardar en otra tabla los cambios hechos (INSERT/UPDATE/DELETE). |
# | **Uso 3: Automatización de tablas** | Crear o modificar filas en otras tablas en respuesta a un evento. |
# | **Cuándo usar BEFORE** | Cuando necesitas validar o modificar datos antes de aceptar un insert/update. |
# | **Cuándo usar AFTER** | Cuando quieres registrar o manipular datos después de que el cambio ya ocurrió. |
# | **Limitaciones** | No sustituye lógica de aplicación, no se ejecuta manualmente, no procesa sets completos (solo row-by-row). |
# | **Ejemplo conceptual** | AFTER DELETE en una tabla de "follows" → registrar un "unfollow" en una tabla histórica. |
# | **Importancia del nombre del trigger** | Sirve para identificarlo y eliminarlo; no afecta su ejecución. |
# | **Qué NO hacen los triggers** | No se usan para cálculos masivos, no reemplazan validaciones completas del backend. |
# | **Casos donde NO se recomiendan** | Reglas complejas que deberían manejarse en el código de aplicación. |
# | **Ventajas** | Automatización, consistencia, auditoría interna, control de datos. |
# | **Desventajas** | Puede ocultar lógica, dificultar debugging, afectar rendimiento si se usan en exceso. |

# %%
# %%sql
# CREATE TABLE users(
#     username VARCHAR(50),
#     age INTEGER
# )
# Out:
#  * sqlite:///tvshows.db
# Done.
# []

# %%
# %sql SELECT * FROM display_tables
# Out:
#  * sqlite:///tvshows.db
# Done.
# [('reviewers',), ('sqlite_sequence',), ('series',), ('reviews',), ('users',)]

# %%
# %sql INSERT INTO users VALUES('colt', 35);
# Out:
#  * sqlite:///tvshows.db
# 1 rows affected.
# []

# %%
# %sql SELECT * FROM users;
# Out:
#  * sqlite:///tvshows.db
# Done.
# [('colt', 35)]

# %% [markdown]
# ```sql
# DELIMITER $$
# CREATE TRIGGER age_check
#     BEFORE INSERT ON users FOR EACH ROW
#     BEGIN
#         IF NEW.age < 0
#         THEN
#             SIGNAL SQLSTATE '45000'
#                 SET MESSAGE_TEXT = 'Age cannot be negative';
#         END IF;
#     END;
# $$
#
# DELIMITER ;

# %% [markdown]
# Delimiter es una forma de decirle al codigo donde termina una instruccion y empieza otra, en este caso el ; es el delimitador. y $$ es otro delimitador que se usa para definir procedimientos almacenados o triggers en SQL.

# %% [markdown]
# ```sql
# DELIMITER $$
# CREATE TRIGGER capture_unfollow
#     AFTER DELET ON users FOR EACH ROW
#     BEGIN
#         INSERT INTO unflollows(follower_id, followe_id)
#         VALUES(OLD.follower_id, OLD.followee,id);
#     END;
# $$
#
# DELIMITER ;

# %% [markdown]
# #### **TRIGGER MANAGE** ###

# %% [markdown]
# ```sql
# SHOW TRIGGERS;

# %% [markdown]
# ```sql
# DROP TRIGGER name
