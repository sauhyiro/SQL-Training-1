# %% [markdown]
# ## Creatging_databases_tables ##

# %% [markdown]
# #### **Cargar el SQL en Jupyter** ####

# %%
# %load_ext sql
# %sql sqlite://

# %% [markdown]
# #### **Creacion de Base de datos** ###
# - CREATE DATABASE prueba1;

# %%
"Crea una base de datos para SQLite"
# %sql sqlite:///prueba.db

# %% [markdown]
# #### **Eliminar base de datos** ###
#
# - DROP DATABASE prueba1;

# %% [markdown]
# Se elimina directamente en el sqlite

# %% [markdown]
# #### **Mostrar base de datos** ####
# - show databases;

# %%
"Muestra un listado de base de datos para sqlite"
# %sql PRAGMA database_list;
# Out:
#    sqlite://
#  * sqlite:///prueba.db
# Done.
# [(0, 'main', 'c:\\Users\\aguiar3\\OneDrive - Faurecia\\IA Project\\Training\\SQL\\UDEMY Training\\MySQLTraining1-Colt Steele\\prueba.db')]

# %% [markdown]
# #### **Usar base de datos** ###
# - USE prueba1,

# %%
"Usar la base de datos que necesitas"
# %sql sqlite:///prueba.db
